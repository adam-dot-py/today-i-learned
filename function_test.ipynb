# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.random.randn(50).cumsum())

# %%
sum = 0
for i in range(10000):
    if i % 3 == 0 or i % 5 == 0:
        sum += i

sum
# Out:
# 23331668

# %%
import json
import pandas as pd
import ast


df = pd.read_csv('example.csv')

df['coursepackage'] = df['coursepackage'].apply(ast.literal_eval)

# df['coursepackage'] = df['coursepackage'].apply(lambda x: json.dumps(x))

df
# Out:
#    Application_ID                                      coursepackage
# 0         4925694  {'course': [{'Course_Code': '2CMR', 'Intake_St...
# 1         4899353  {'course': [{'Course_Code': 'DSP', 'Intake_Stu...

# %%
# import json
# import pandas as pd
# import ast
# from pyspark.sql.functions import explode
# import pyspark
# from pyspark.sql import SparkSession


# df = pd.read_csv('example.csv')
# df['coursepackage'] = df['coursepackage'].apply(ast.literal_eval)

# spark = SparkSession.builder.appName('testing').getOrCreate()
# spark_df = spark.createDataFrame(data=df)

# df2 = spark_df.select(spark_df.Application_ID, explode(spark_df.coursepackage))

# spark_df.show()

# # df2 = df.select(df.Application_ID, explode(df.coursepackage))

# # df2

# # # df['coursepackage'] = df['coursepackage'].apply(ast.literal_eval)

# # df['coursepackage'] = df['coursepackage'].apply(lambda x: json.loads(x))
# # df['coursepackage'] = df['coursepackage'].apply(lambda x: json.dumps(x))


# df
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# C:\Users\ADAM~1.LOW\AppData\Local\Temp/ipykernel_11900/2141448701.py in <module>
#      15 df2 = spark_df.select(spark_df.Application_ID, explode(spark_df.coursepackage))
#      16
# ---> 17 spark_df.show()
#      18
#      19 # df2 = df.select(df.Application_ID, explode(df.coursepackage))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pyspark\sql\dataframe.py in show(self, n, truncate, vertical)
#     492
#     493         if isinstance(truncate, bool) and truncate:
# --> 494             print(self._jdf.showString(n, 20, vertical))
#     495         else:
#     496             try:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1319
#    1320         answer = self.gateway_client.send_command(command)
# ...
