# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.random.randn(50).cumsum())

# %%
sum = 0

for i in range(10000):
    if i % 3 == 0 or i % 5 == 0: 
        sum += i

sum
# Out:
# 23331668
